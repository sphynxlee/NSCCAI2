# %% [markdown]
# Create some toy data to work with. You will later - as an activity - experiment with some real data.

# %%
import numpy as np

def generateFakeData(n,k):
  np.random.seed(10)
  points_per_cluster = float(n)/k
  X = []
  for i in range(k):
    stepsTakenCentroid = np.random.uniform(25000.0,3000.0)
    ageCentroid  = np.random.uniform(70.0,20.0)
    for j in range(int(points_per_cluster)):
      # this paper for stddev: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5774986/
      X.append([np.random.normal(stepsTakenCentroid,1500.0),np.random.normal(ageCentroid,2.0)])
  X = np.array(X)
  return(X)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# Set random seed for reproducibility
np.random.seed(42)

# Create synthetic data with 5 clusters
SynData, y = make_blobs(n_samples=500, centers=5, random_state=42, cluster_std=1.0)

# Visualize the generated data
plt.scatter(SynData[:, 0], SynData[:, 1], c=y, cmap='viridis', edgecolors='k')
plt.title("Synthetic Data with 5 Clusters")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %%
data = generateFakeData(100,5)
print(data)
# Out:
# [[1.00283256e+04 7.03929605e+01]
#  [5.71284541e+03 6.89456348e+01]
#  [8.96294981e+03 6.75222314e+01]
#  [8.42921323e+03 6.91794996e+01]
#  [8.03738299e+03 6.86132021e+01]
#  [8.68048513e+03 7.13684773e+01]
#  [6.58334734e+03 7.10189507e+01]
#  [8.37389104e+03 6.98526778e+01]
#  [6.32604253e+03 6.92326763e+01]
#  [1.02577514e+04 6.68027928e+01]
#  [5.06435343e+03 6.54756579e+01]
#  [8.43005109e+03 7.37323372e+01]
#  [9.71648273e+03 7.23076470e+01]
#  [8.17966967e+03 7.17583953e+01]
#  [7.62407387e+03 7.01888109e+01]
#  [7.62997007e+03 6.78637845e+01]
#  [8.23000829e+03 6.80101185e+01]
#  [9.99365547e+03 6.93524291e+01]
#  [8.63126083e+03 6.82871379e+01]
#  [9.91565424e+03 6.74984635e+01]
#  [1.70796924e+04 2.48245016e+01]
#  [1.72819557e+04 2.53777807e+01]
#  [1.79801321e+04 2.64275159e+01]
#  [1.93365715e+04 2.55083355e+01]
#  [1.84499844e+04 2.63813644e+01]
#  [1.76790238e+04 2.72194961e+01]
#  [1.97521796e+04 2.62103376e+01]
#  [2.20808979e+04 2.76380939e+01]
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(SynData[:,0],SynData[:,1])

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import scale


model = KMeans(n_clusters=4)
model = model.fit(scale(SynData))
print(model.labels_)

plt.figure(figsize=(8,6))
plt.scatter(SynData[:,0],SynData[:,1],c=model.labels_.astype(np.float64))
plt.show()
# Out:
# C:\Users\W0485258\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [2 2 2 2 1 2 1 2 0 0 2 2 2 2 3 3 2 3 1 2 2 3 1 3 0 3 0 3 1 2 0 0 0 2 2 0 3
#  2 3 0 3 2 0 3 0 1 0 3 1 1 1 0 2 2 2 2 2 3 3 1 1 0 2 1 0 2 2 1 2 2 2 2 2 2
#  2 2 2 0 3 1 1 0 2 3 1 3 2 2 0 2 2 1 2 1 0 2 0 1 2 2 2 2 0 2 0 1 1 1 1 1 2
#  0 2 2 1 2 3 3 1 2 3 2 2 2 2 1 0 2 1 2 2 3 2 3 2 3 1 2 2 2 1 1 3 1 1 3 2 1
#  3 2 3 2 0 0 0 3 2 2 1 0 2 0 1 3 3 1 3 2 2 3 2 2 3 2 1 2 0 0 1 2 0 0 1 2 3
#  0 1 0 0 2 2 2 2 0 3 3 3 2 3 2 2 0 0 3 2 0 0 3 2 2 1 2 3 2 2 2 3 3 1 0 0 3
#  0 2 0 2 2 0 3 2 2 0 0 2 1 2 3 1 0 1 3 3 0 1 2 2 1 3 0 2 2 1 2 0 1 0 2 2 0
#  2 2 2 0 2 0 3 1 2 0 2 3 0 0 2 2 0 0 0 2 2 3 0 1 2 0 3 2 1 2 2 1 3 0 0 2 3
# ...
